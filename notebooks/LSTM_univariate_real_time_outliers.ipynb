# %%
import keras
import math
import pandas as pd
import numpy as np
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
import time
from torch.utils.data import Dataset, DataLoader
import pickle
pd.set_option('display.max_rows', 500)
import os
import tensorflow as tf
import torch
import torch.nn as nn
from math import sqrt
# import rmse from sklearn
from sklearn.metrics import mean_squared_error


# define random seeds for Neural Networks
torch.manual_seed(0)
np.random.seed(0)
tf.random.set_seed(0)
# ignore warnings jupyter notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # OWRI FRAMEWORK

# %%
def merge_trejectory_data(results, trajectory, direction):
    data = pd.DataFrame()
    for intersection_name in results[trajectory][direction]['raw']:
        intersection = results[trajectory][direction]['raw'][intersection_name]
        intersection = intersection.rename(columns={"cars": intersection_name})
        intersection = intersection.set_index(pd.DatetimeIndex(intersection['timestamp']))
        intersection = intersection.drop(columns=['timestamp'])
        data = pd.merge(data, intersection, left_index=True, right_index=True, how='outer')
    data.dropna(inplace=True)
    return data

# %%
def merge_trejectory_data_metr(results):
    data = pd.DataFrame()
    for intersection_name in results['raw']:
        intersection = results['raw'][intersection_name]
        intersection = intersection.rename(columns={"cars": intersection_name})
        intersection = intersection.set_index(pd.DatetimeIndex(intersection['timestamp']))
        intersection = intersection.drop(columns=['timestamp'])
        data = pd.merge(data, intersection, left_index=True, right_index=True, how='outer')
    data.dropna(inplace=True)
    return data

# %%
def preprocess_df(df,n_obs, n_features, sequence_length):
    #do scaling:
    scaler = StandardScaler()
    df_train = df.values
    train_X, train_y = df_train[:, :n_obs], df_train[:, -n_features]
    scl = scaler.fit(train_X) # fit only on training data
    train_X = scl.transform(train_X)
    train_X = train_X.reshape((train_X.shape[0], sequence_length, n_features))
    return train_X, train_y, scl

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
class LSTM_uni(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device = 'mps',layer_dim=1, dropout_prob = 0.2):
        super(LSTM_uni, self).__init__()
        self.hidden_dim = hidden_dim # number of hidden units in hidden state
        self.layer_dim = layer_dim # number of stacked lstm layers
        # batch_first=True causes input/output tensors to be of shape
        # (batch_dim, seq_dim, feature_dim)
        self.lstm = nn.LSTM(input_dim, hidden_dim, layer_dim, batch_first=True, dropout=dropout_prob)
        self.fc = nn.Linear(hidden_dim, output_dim) # fully connected layer

    def forward(self, x, future=False):
        # input x is expected to be of shape (batch_dim, seq_dim, feature_dim)
        # hidden and cell states are expected along with input x in LSTMs = (h_0, c_0)
        # Initialize hidden state with zeros (layer_dim, batch_size, hidden_dim)
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim, device=device).requires_grad_()
        c0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim, device=device).requires_grad_()

        # LSTM output is Outputs: output, (h_n, c_n)
        # output is of shape (batch_dim, seq_dim, hidden_dim), h_n and c_n are of shape (layer_dim, batch_dim, hidden_dim)
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        out = out[:, -1, :] # only take the last output of the sequence
        out = self.fc(out) # fully connected layer

        return out

# %%
def train_model(model, train_X,train_y, loss_fn, optimiser, device, epochs=100):
    history = {}
    history['train_loss'] = []

    train_X_loader = DataLoader(train_X, batch_size=128, shuffle=False)
    train_y_loader = DataLoader(train_y, batch_size=128, shuffle=False)

    for epoch in range(epochs):
        history[epoch] = []
        ep_start = time.time()
        running_loss = 0.0
        for bx, data in enumerate(zip(train_X_loader,train_y_loader)):
            X = data[0].to(device)
            y = data[1].to(device)
            bt = model(X)
            loss = loss_fn(bt.reshape(-1), y.reshape(-1)) # calculate loss for input and recreated output
            history[epoch].append(loss.item())
            optimiser.zero_grad()
            loss.backward()
            optimiser.step()
            running_loss += loss.item()
        epoch_loss = running_loss/train_X.shape[0]
        history['train_loss'].append(epoch_loss)

    return history, model

# %%
def model_evaluation( model, test_X, device):
    test_X_loader = DataLoader(test_X, batch_size=128, shuffle=False)
    model = model.eval()
    preds = []
    with torch.no_grad():
        for bx, data in enumerate(test_X_loader):
            X = data.to(device)
            bt = model(X)
            preds.append(bt.cpu().numpy())
    preds = np.vstack(preds)
    preds = preds.reshape(-1)
    return preds

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    checkpoint = torch.load(checkpoint_fpath)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    return model, optimizer

# %%
def test_then_train_weighted_model(data, ae_score, number_of_cols, target, results_load_path, results_save_path, hidden_size, output_pred, num_layers, dropout, device, sequence_length, epoch_train, epoch_retrain,fixed_base_corr_df, pre_trained, static , base ):
    result_dict = {}

    # ------------------------------------ data processing ---------------------------------------- #
    if static == False:
        top_corr_df = ae_score.corr()[target].sort_values(ascending=False)[:number_of_cols] # get the top correlated intersections
    else:
        top_corr_df = fixed_base_corr_df
    isct_inc = top_corr_df.index.tolist()
    print("correlated intersections: {}".format(isct_inc))
    df = data[isct_inc].copy(deep=True)
    df = df.mul(top_corr_df, axis=1)
    df = df.astype('float32')
    n_features = len(isct_inc) # number of features (correlated intersections)
    n_obs = sequence_length * n_features # number of columns in the input
    reframed = series_to_supervised(df, sequence_length, output_pred)
    train_X, train_y, scl = preprocess_df(reframed, n_obs, n_features, sequence_length)


    # # # ------------------------------------ modelling ---------------------------------------------- #
    # define model, loss function and optimizer
    model = LSTM_uni(input_dim = n_features, hidden_dim = hidden_size, output_dim = output_pred, layer_dim = num_layers, dropout_prob= dropout, device = device)
    model = model.to(device)
    loss_fn = torch.nn.MSELoss()
    optimiser = torch.optim.Adam(model.parameters(), lr=0.01)
    if pre_trained==True:
        model, optimiser = load_ckp(results_load_path, model, optimiser)
    

    # ------------------------------------ testing ---------------------------------------------- #
    yhat = model_evaluation( model, train_X , device)
    result_dict['RMSE'] = sqrt(mean_squared_error(yhat,train_y))
    result_dict['MAE'] = mean_absolute_error(yhat,train_y)
    result_dict['R2'] = r2_score(yhat,train_y)
    result_dict['df'] = pd.DataFrame({"Real":train_y,"Predicted":yhat})
    print("RMSE: {}".format(result_dict['RMSE']))


   # ------------------------------------ training ---------------------------------------------- #
    if not base:
        start = time.time()
        if pre_trained==False:
            history, model = train_model(model, train_X,train_y, loss_fn, optimiser, device, epochs=epoch_train)
        else:
            history, model = train_model(model, train_X,train_y, loss_fn, optimiser, device, epochs=epoch_retrain)
        end = time.time()
        checkpoint = {'state_dict': model.state_dict(),'optimizer': optimiser.state_dict()}
        torch.save(checkpoint, results_save_path)
        print("Training time: {}".format(end-start))
        result_dict['history'] = history
        result_dict['intersedctions'] = isct_inc
        result_dict['train_time'] = end-start

    
    return result_dict, top_corr_df

# %% [markdown]
# #### ---------------------------- Hauge data processing ----------------------------

# %%
# results save path
outlier_model_name = 'PW-AE'
data_name = 'hauge'
base_result_path = f'../results/{data_name}/real_time_modeling'

# %%
with open(f'../data/{data_name}/processed/featured_fpds_raw.pickle', 'rb') as f:
    results = pickle.load(f)

# %%
# load data of correlated results from pickle file
with open(f'../results/{data_name}/outlier_scores/{outlier_model_name}/correlated_results.pickle', 'rb') as f:
    correlated_results = pickle.load(f)

# %%
thresholds = [0,0.05,0.1,0.25,0.5, 1] # thresholds for the percentage of correlated columns to keep
target_intersections={"T1":{"North":"K504", "South":"K561"}, # get target intersections for each trajectory and direction
                      "T2":{"North":"K703", "South":"K206"}}
# declare variables
threshold = 0.05
time_window = 3
epoch_train = 100
epoch_retrain = 20
batch_size = 64
learning_rate = 0.1
hidden_size = 32
num_layers = 1
dropout = 0.2
sequence_length = 12
output_pred = 1 # number of time steps to predict
base_train_portion = 0.5 # percentage of data to use for training
device = 'mps' if torch.backends.mps.is_available() else 'cpu'

# %%
errors={}
for trajectory in results.keys():
    errors[trajectory]={}
    for direction in results[trajectory]:
        print(f"\n \n ------------------------ Starting trajectory {trajectory}, direction {direction} and threshold: {threshold} ------------------------")
        key = trajectory+"_"+direction
        target = target_intersections[trajectory][direction]
        errors[trajectory][direction]={}
        errors[trajectory][direction][threshold]={}
        errors[trajectory][direction][threshold]['incremental_weighted_update']={}
        errors[trajectory][direction][threshold]['incremental_static_update']={}
        errors[trajectory][direction][threshold]['No_update']={}

        # ------------------------------------ data processing ---------------------------------------- #
        data = merge_trejectory_data(results, trajectory, direction)# get raw data of the current trajectory and direction
        ae_score = correlated_results[key] # AE scores of the current trajectory and direction
        data_size = data.shape[0]
        model_start_time  = data.index[0]
        model_end_time = data.index[-1]
        baseline_time = data.iloc[int(data_size*base_train_portion)].name
        incremental_time = baseline_time
        base_ae = ae_score[ae_score.index<=baseline_time]
        stream_ae = ae_score[ae_score.index>baseline_time]
        base_data = data[data.index<=baseline_time]
        stream_data = data[data.index>baseline_time]
        number_of_cols = math.ceil(len(ae_score.columns)*threshold) # number of outlier weighted intersections
        if number_of_cols==0: # if threshold is 0, then use the target intersection only
            number_of_cols=1

        # ------------------------------------ training base model ---------------------------------------- #
        print(f"training from {model_start_time} to {baseline_time}")
        exp_name = f'univariate_{outlier_model_name}_real_time_base_model.pt'
        results_save_path = os.path.join(base_result_path, exp_name)
        results_save_weighted_path  = results_save_path
        base_model_path = results_save_path
        results_load_path = "None"
        results_load_weighted_path = "None"
        fixed_base_corr_df = "None"
        model_results, fixed_base_corr_df = test_then_train_weighted_model(base_data, base_ae, number_of_cols, target, results_load_path, base_model_path, hidden_size, output_pred, num_layers, dropout, device, sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained=False, static = False, base=False)
        errors[trajectory][direction][threshold]['base_model'] = model_results

        # # ------------------------------------ incremental training ---------------------------------------- #
        incremental_time = incremental_time + pd.DateOffset(hours=time_window)
        while(incremental_time<model_end_time):
            print(f"\n\ntraining from {baseline_time} to {incremental_time}")
            incremental_ae = stream_ae[(stream_ae.index>baseline_time) & (stream_ae.index<=incremental_time)]
            incremental_data = stream_data[(stream_data.index>baseline_time) & (stream_data.index<=incremental_time)]
            exp_name = f'univariate_real_time_{outlier_model_name}_incremental_static_{incremental_time}.pkl'
            exp_name_weighted = f'univariate_real_time_{outlier_model_name}_incremental_weighted_{incremental_time}.pkl'
            results_load_path = results_save_path
            results_save_path = os.path.join(base_result_path, exp_name)
            results_load_weighted_path = results_save_weighted_path
            results_save_weighted_path = os.path.join(base_result_path, exp_name_weighted)

            # ------------------------------------ training incremental models ---------------------------------------- #
            print("training incremental weighted update model")
            model_results,top_corr_df = test_then_train_weighted_model(incremental_data, incremental_ae, number_of_cols, target, results_load_weighted_path, results_save_weighted_path, hidden_size, output_pred, num_layers, dropout, device,sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained=True, static = False, base=False)
            errors[trajectory][direction][threshold]['incremental_weighted_update'][incremental_time] = model_results

            print("training incremental static update model")
            model_results,top_corr_df = test_then_train_weighted_model(incremental_data, incremental_ae, number_of_cols, target, results_load_path, results_save_path, hidden_size, output_pred, num_layers, dropout, device, sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained=True, static = True, base=False)
            errors[trajectory][direction][threshold]['incremental_static_update'][incremental_time] = model_results

            print("training No update model")
            model_results,top_corr_df = test_then_train_weighted_model(incremental_data, incremental_ae, number_of_cols, target, base_model_path, results_save_weighted_path, hidden_size, output_pred, num_layers, dropout, device, sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained=True, static = True, base=True)
            errors[trajectory][direction][threshold]['No_update'][incremental_time] = model_results


            baseline_time = incremental_time # update baseline time
            incremental_time = incremental_time + pd.DateOffset(hours=time_window) # update incremental time
# Out:
#
#  ------------------------ Starting trajectory T1, direction North and threshold: 0.05 ------------------------
# training from 2018-01-01 00:00:00 to 2019-02-16 00:00:00
# correlated intersections: ['K504']
# RMSE: 47.17308088885943
# Training time: 579.5522727966309
#
#
# training from 2019-02-16 00:00:00 to 2019-02-16 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 45.75887625214779
# Training time: 0.1323239803314209
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 45.75887625214779
# Training time: 0.13474512100219727
# training No update model
# correlated intersections: ['K504']
# RMSE: 45.75887625214779
#
#
# training from 2019-02-16 03:00:00 to 2019-02-16 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 12.326691634828716
# Training time: 0.12235403060913086
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 12.326691634828716
# Training time: 0.12459921836853027
# training No update model
# correlated intersections: ['K504']
# RMSE: 44.61834000328158
#
#
# training from 2019-02-16 06:00:00 to 2019-02-16 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 23.025433617235503
# Training time: 0.11684918403625488
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 23.025433617235503
# Training time: 0.12185096740722656
# training No update model
# correlated intersections: ['K504']
# RMSE: 20.0443942407476
#
#
# training from 2019-02-16 09:00:00 to 2019-02-16 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 57.13720465904856
# Training time: 0.12168717384338379
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 57.13720465904856
# Training time: 0.1282057762145996
# training No update model
# correlated intersections: ['K504']
# RMSE: 31.529113878646452
#
#
# training from 2019-02-16 12:00:00 to 2019-02-16 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 64.9871419073131
# Training time: 0.12096977233886719
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 64.9871419073131
# Training time: 0.12181305885314941
# training No update model
# correlated intersections: ['K504']
# RMSE: 51.13039349224564
#
#
# training from 2019-02-16 15:00:00 to 2019-02-16 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 22.119125362163608
# Training time: 0.12099099159240723
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 22.119125362163608
# Training time: 0.12385988235473633
# training No update model
# correlated intersections: ['K504']
# RMSE: 24.10403780846427
#
#
# training from 2019-02-16 18:00:00 to 2019-02-16 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 40.54677715546961
# Training time: 0.12410712242126465
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 40.54677715546961
# Training time: 0.1214292049407959
# training No update model
# correlated intersections: ['K504']
# RMSE: 22.595876591006945
#
#
# training from 2019-02-16 21:00:00 to 2019-02-17 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 35.36538662716785
# Training time: 0.1234128475189209
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 35.36538662716785
# Training time: 0.12125897407531738
# training No update model
# correlated intersections: ['K504']
# RMSE: 27.23788098667977
#
#
# training from 2019-02-17 00:00:00 to 2019-02-17 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 27.706578279904374
# Training time: 0.1252286434173584
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 27.706578279904374
# Training time: 0.12244200706481934
# training No update model
# correlated intersections: ['K504']
# RMSE: 42.346789847065885
#
#
# training from 2019-02-17 03:00:00 to 2019-02-17 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 22.43840309812064
# Training time: 0.1204979419708252
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 22.43840309812064
# Training time: 0.11630725860595703
# training No update model
# correlated intersections: ['K504']
# RMSE: 46.64721477735166
#
#
# training from 2019-02-17 06:00:00 to 2019-02-17 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 7.966233278667308
# Training time: 0.11576294898986816
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 7.966233278667308
# Training time: 0.12217378616333008
# training No update model
# correlated intersections: ['K504']
# RMSE: 35.48238655811324
#
#
# training from 2019-02-17 09:00:00 to 2019-02-17 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 63.84381309651801
# Training time: 0.11962294578552246
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 63.84381309651801
# Training time: 0.12443804740905762
# training No update model
# correlated intersections: ['K504']
# RMSE: 36.70365547456156
#
#
# training from 2019-02-17 12:00:00 to 2019-02-17 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 94.06723410013713
# Training time: 0.11578798294067383
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 94.06723410013713
# Training time: 0.12206411361694336
# training No update model
# correlated intersections: ['K504']
# RMSE: 71.0136980624161
#
#
# training from 2019-02-17 15:00:00 to 2019-02-17 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 17.73802791398592
# Training time: 0.11698317527770996
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 17.73802791398592
# Training time: 0.11882495880126953
# training No update model
# correlated intersections: ['K504']
# RMSE: 20.065729849778624
#
#
# training from 2019-02-17 18:00:00 to 2019-02-17 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 38.5292366287643
# Training time: 0.12269806861877441
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 38.5292366287643
# Training time: 0.12116003036499023
# training No update model
# correlated intersections: ['K504']
# RMSE: 26.117221386083312
#
#
# training from 2019-02-17 21:00:00 to 2019-02-18 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 43.57001481989936
# Training time: 0.11850881576538086
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 43.57001481989936
# Training time: 0.1229550838470459
# training No update model
# correlated intersections: ['K504']
# RMSE: 38.683650353702404
#
#
# training from 2019-02-18 00:00:00 to 2019-02-18 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 42.709677792608524
# Training time: 0.11891031265258789
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 42.709677792608524
# Training time: 0.12157988548278809
# training No update model
# correlated intersections: ['K504']
# RMSE: 45.5179984576843
#
#
# training from 2019-02-18 03:00:00 to 2019-02-18 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 31.01874885874217
# Training time: 0.12031388282775879
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 31.01874885874217
# Training time: 0.1168980598449707
# training No update model
# correlated intersections: ['K504']
# RMSE: 37.060070865273076
#
#
# training from 2019-02-18 06:00:00 to 2019-02-18 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 29.09431537279609
# Training time: 0.11428403854370117
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 29.09431537279609
# Training time: 0.12618279457092285
# training No update model
# correlated intersections: ['K504']
# RMSE: 20.16235978136302
#
#
# training from 2019-02-18 09:00:00 to 2019-02-18 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 19.44826746581492
# Training time: 0.13338685035705566
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 19.44826746581492
# Training time: 0.13842296600341797
# training No update model
# correlated intersections: ['K504']
# RMSE: 13.310423496539341
#
#
# training from 2019-02-18 12:00:00 to 2019-02-18 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 31.778456543592057
# Training time: 0.12190008163452148
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 31.778456543592057
# Training time: 0.12112808227539062
# training No update model
# correlated intersections: ['K504']
# RMSE: 24.15536185503451
#
#
# training from 2019-02-18 15:00:00 to 2019-02-18 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 35.47593023412582
# Training time: 0.12377810478210449
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 35.47593023412582
# Training time: 0.12142705917358398
# training No update model
# correlated intersections: ['K504']
# RMSE: 28.706689736793603
#
#
# training from 2019-02-18 18:00:00 to 2019-02-18 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 16.01108929675773
# Training time: 0.11760115623474121
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 16.01108929675773
# Training time: 0.11928868293762207
# training No update model
# correlated intersections: ['K504']
# RMSE: 21.593681456792446
#
#
# training from 2019-02-18 21:00:00 to 2019-02-19 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 32.19218715872688
# Training time: 0.11920022964477539
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 32.19218715872688
# Training time: 0.12147974967956543
# training No update model
# correlated intersections: ['K504']
# RMSE: 35.99350086463093
#
#
# training from 2019-02-19 00:00:00 to 2019-02-19 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 40.93489525348834
# Training time: 0.11689400672912598
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 40.93489525348834
# Training time: 0.12079381942749023
# training No update model
# correlated intersections: ['K504']
# RMSE: 45.094338776041916
#
#
# training from 2019-02-19 03:00:00 to 2019-02-19 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 24.775162053660846
# Training time: 0.11681413650512695
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 24.775162053660846
# Training time: 0.13467812538146973
# training No update model
# correlated intersections: ['K504']
# RMSE: 37.304477257260956
#
#
# training from 2019-02-19 06:00:00 to 2019-02-19 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 35.20178821529792
# Training time: 0.11678886413574219
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 35.20178821529792
# Training time: 0.12677788734436035
# training No update model
# correlated intersections: ['K504']
# RMSE: 22.361225000990483
#
#
# training from 2019-02-19 09:00:00 to 2019-02-19 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 21.402864553231755
# Training time: 0.1154320240020752
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 21.402864553231755
# Training time: 0.12073326110839844
# training No update model
# correlated intersections: ['K504']
# RMSE: 14.837140798358439
#
#
# training from 2019-02-19 12:00:00 to 2019-02-19 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 28.915162266304485
# Training time: 0.12299895286560059
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 28.915162266304485
# Training time: 0.11572909355163574
# training No update model
# correlated intersections: ['K504']
# RMSE: 19.974558861436325
#
#
# training from 2019-02-19 15:00:00 to 2019-02-19 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 37.86975746256421
# Training time: 0.12136411666870117
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 37.86975746256421
# Training time: 0.12083816528320312
# training No update model
# correlated intersections: ['K504']
# RMSE: 33.18054931038759
#
#
# training from 2019-02-19 18:00:00 to 2019-02-19 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 15.265271154420047
# Training time: 0.12265205383300781
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 15.265271154420047
# Training time: 0.12359189987182617
# training No update model
# correlated intersections: ['K504']
# RMSE: 20.226472726963774
#
#
# training from 2019-02-19 21:00:00 to 2019-02-20 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 29.45106818912463
# Training time: 0.1200859546661377
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 29.45106818912463
# Training time: 0.12128996849060059
# training No update model
# correlated intersections: ['K504']
# RMSE: 35.374296039815405
#
#
# training from 2019-02-20 00:00:00 to 2019-02-20 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 40.21963625674653
# Training time: 0.12274026870727539
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 40.21963625674653
# Training time: 0.11624312400817871
# training No update model
# correlated intersections: ['K504']
# RMSE: 44.52939003791134
#
#
# training from 2019-02-20 03:00:00 to 2019-02-20 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 25.781769644384262
# Training time: 0.12184596061706543
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 25.781769644384262
# Training time: 0.1136927604675293
# training No update model
# correlated intersections: ['K504']
# RMSE: 34.69404323139907
#
#
# training from 2019-02-20 06:00:00 to 2019-02-20 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 33.74466646224907
# Training time: 0.12170290946960449
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 33.74466646224907
# Training time: 0.12425398826599121
# training No update model
# correlated intersections: ['K504']
# RMSE: 25.42619263619027
#
#
# training from 2019-02-20 09:00:00 to 2019-02-20 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 17.863426890260218
# Training time: 0.11751294136047363
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 17.863426890260218
# Training time: 0.11462211608886719
# training No update model
# correlated intersections: ['K504']
# RMSE: 13.452886244796307
#
#
# training from 2019-02-20 12:00:00 to 2019-02-20 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 27.157042251461338
# Training time: 0.12658166885375977
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 27.157042251461338
# Training time: 0.12128591537475586
# training No update model
# correlated intersections: ['K504']
# RMSE: 19.807554187250364
#
#
# training from 2019-02-20 15:00:00 to 2019-02-20 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 33.24386654837156
# Training time: 0.12153220176696777
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 33.24386654837156
# Training time: 0.12289977073669434
# training No update model
# correlated intersections: ['K504']
# RMSE: 27.902706591946416
#
#
# training from 2019-02-20 18:00:00 to 2019-02-20 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 16.880170468016516
# Training time: 0.11919522285461426
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 16.880170468016516
# Training time: 0.12197303771972656
# training No update model
# correlated intersections: ['K504']
# RMSE: 22.460470783194513
#
#
# training from 2019-02-20 21:00:00 to 2019-02-21 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 26.403920015548827
# Training time: 0.11851286888122559
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 26.403920015548827
# Training time: 0.12122011184692383
# training No update model
# correlated intersections: ['K504']
# RMSE: 33.031992807399995
#
#
# training from 2019-02-21 00:00:00 to 2019-02-21 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 37.50195795669791
# Training time: 0.12139892578125
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 37.50195795669791
# Training time: 0.1156308650970459
# training No update model
# correlated intersections: ['K504']
# RMSE: 44.97234393213233
#
#
# training from 2019-02-21 03:00:00 to 2019-02-21 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 23.667604812868685
# Training time: 0.11685872077941895
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 23.667604812868685
# Training time: 0.12168383598327637
# training No update model
# correlated intersections: ['K504']
# RMSE: 39.91920551250989
#
#
# training from 2019-02-21 06:00:00 to 2019-02-21 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 42.16971413276432
# Training time: 0.12183308601379395
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 42.16971413276432
# Training time: 0.1211400032043457
# training No update model
# correlated intersections: ['K504']
# RMSE: 27.59809718552565
#
#
# training from 2019-02-21 09:00:00 to 2019-02-21 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 22.676191385718166
# Training time: 0.11877298355102539
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 22.676191385718166
# Training time: 0.12158083915710449
# training No update model
# correlated intersections: ['K504']
# RMSE: 15.154819822181109
#
#
# training from 2019-02-21 12:00:00 to 2019-02-21 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 27.220690722646417
# Training time: 0.12266111373901367
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 27.220690722646417
# Training time: 0.12393808364868164
# training No update model
# correlated intersections: ['K504']
# RMSE: 18.739467256478786
#
#
# training from 2019-02-21 15:00:00 to 2019-02-21 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 40.739514084148084
# Training time: 0.12130880355834961
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 40.739514084148084
# Training time: 0.12225890159606934
# training No update model
# correlated intersections: ['K504']
# RMSE: 34.17883123927459
#
#
# training from 2019-02-21 18:00:00 to 2019-02-21 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 16.902945429983035
# Training time: 0.1268458366394043
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 16.902945429983035
# Training time: 0.12205386161804199
# training No update model
# correlated intersections: ['K504']
# RMSE: 15.71435582529256
#
#
# training from 2019-02-21 21:00:00 to 2019-02-22 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 26.43268254534467
# Training time: 0.12341499328613281
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 26.43268254534467
# Training time: 0.1222531795501709
# training No update model
# correlated intersections: ['K504']
# RMSE: 32.7823950437531
#
#
# training from 2019-02-22 00:00:00 to 2019-02-22 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 37.88756592032784
# Training time: 0.12304997444152832
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 37.88756592032784
# Training time: 0.12120699882507324
# training No update model
# correlated intersections: ['K504']
# RMSE: 45.83108156163647
#
#
# training from 2019-02-22 03:00:00 to 2019-02-22 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 28.707682638632967
# Training time: 0.12244892120361328
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 28.707682638632967
# Training time: 0.12597012519836426
# training No update model
# correlated intersections: ['K504']
# RMSE: 36.82339642691943
#
#
# training from 2019-02-22 06:00:00 to 2019-02-22 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 26.565120504929133
# Training time: 0.12223386764526367
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 26.565120504929133
# Training time: 0.12096095085144043
# training No update model
# correlated intersections: ['K504']
# RMSE: 20.814003646649397
#
#
# training from 2019-02-22 09:00:00 to 2019-02-22 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 22.925295043511028
# Training time: 0.12312889099121094
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 22.925295043511028
# Training time: 0.1152188777923584
# training No update model
# correlated intersections: ['K504']
# RMSE: 17.69741036819326
#
#
# training from 2019-02-22 12:00:00 to 2019-02-22 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 33.236132490554425
# Training time: 0.12198519706726074
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 33.236132490554425
# Training time: 0.12097620964050293
# training No update model
# correlated intersections: ['K504']
# RMSE: 26.73508615177757
#
#
# training from 2019-02-22 15:00:00 to 2019-02-22 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 31.019419832393403
# Training time: 0.11681389808654785
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 31.019419832393403
# Training time: 0.12105917930603027
# training No update model
# correlated intersections: ['K504']
# RMSE: 24.773634597922975
#
#
# training from 2019-02-22 18:00:00 to 2019-02-22 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 19.053161935393508
# Training time: 0.1232447624206543
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 19.053161935393508
# Training time: 0.11481308937072754
# training No update model
# correlated intersections: ['K504']
# RMSE: 21.279532700764147
#
#
# training from 2019-02-22 21:00:00 to 2019-02-23 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 24.764082168031184
# Training time: 0.12350702285766602
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 24.764082168031184
# Training time: 0.12032580375671387
# training No update model
# correlated intersections: ['K504']
# RMSE: 29.768041445548718
#
#
# training from 2019-02-23 00:00:00 to 2019-02-23 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 35.83398645086725
# Training time: 0.13709521293640137
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 35.83398645086725
# Training time: 0.1230018138885498
# training No update model
# correlated intersections: ['K504']
# RMSE: 39.41128815186155
#
#
# training from 2019-02-23 03:00:00 to 2019-02-23 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 33.95398964902265
# Training time: 0.11993789672851562
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 33.95398964902265
# Training time: 0.11826801300048828
# training No update model
# correlated intersections: ['K504']
# RMSE: 46.73280516002651
#
#
# training from 2019-02-23 06:00:00 to 2019-02-23 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 16.239595339389137
# Training time: 0.12259221076965332
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 16.239595339389137
# Training time: 0.12018990516662598
# training No update model
# correlated intersections: ['K504']
# RMSE: 29.43312380389599
#
#
# training from 2019-02-23 09:00:00 to 2019-02-23 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 35.860450691926964
# Training time: 0.11629390716552734
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 35.860450691926964
# Training time: 0.11906909942626953
# training No update model
# correlated intersections: ['K504']
# RMSE: 21.51331786263998
#
#
# training from 2019-02-23 12:00:00 to 2019-02-23 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 62.36402200174693
# Training time: 0.11869597434997559
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 62.36402200174693
# Training time: 0.12111186981201172
# training No update model
# correlated intersections: ['K504']
# RMSE: 47.29490828418398
#
#
# training from 2019-02-23 15:00:00 to 2019-02-23 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 26.53730077682226
# Training time: 0.11818599700927734
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 26.53730077682226
# Training time: 0.12481379508972168
# training No update model
# correlated intersections: ['K504']
# RMSE: 19.675672290372315
#
#
# training from 2019-02-23 18:00:00 to 2019-02-23 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 17.16165403988688
# Training time: 0.1165456771850586
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 17.16165403988688
# Training time: 0.12219691276550293
# training No update model
# correlated intersections: ['K504']
# RMSE: 18.90050677876497
#
#
# training from 2019-02-23 21:00:00 to 2019-02-24 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 23.69779804800899
# Training time: 0.12224411964416504
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 23.69779804800899
# Training time: 0.12015795707702637
# training No update model
# correlated intersections: ['K504']
# RMSE: 29.522496842648977
#
#
# training from 2019-02-24 00:00:00 to 2019-02-24 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 34.412160312072096
# Training time: 0.12260913848876953
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 34.412160312072096
# Training time: 0.1209716796875
# training No update model
# correlated intersections: ['K504']
# RMSE: 42.31964691072502
#
#
# training from 2019-02-24 03:00:00 to 2019-02-24 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 32.90839595626111
# Training time: 0.11696887016296387
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 32.90839595626111
# Training time: 0.1215810775756836
# training No update model
# correlated intersections: ['K504']
# RMSE: 46.776383243009235
#
#
# training from 2019-02-24 06:00:00 to 2019-02-24 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 23.6801475850223
# Training time: 0.12243509292602539
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 23.6801475850223
# Training time: 0.1227731704711914
# training No update model
# correlated intersections: ['K504']
# RMSE: 37.48551152403753
#
#
# training from 2019-02-24 09:00:00 to 2019-02-24 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 39.37194928657965
# Training time: 0.12196612358093262
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 39.37194928657965
# Training time: 0.12018918991088867
# training No update model
# correlated intersections: ['K504']
# RMSE: 24.37421623339277
#
#
# training from 2019-02-24 12:00:00 to 2019-02-24 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 72.28567120611629
# Training time: 0.12231683731079102
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 72.28567120611629
# Training time: 0.12118792533874512
# training No update model
# correlated intersections: ['K504']
# RMSE: 55.63907827462637
#
#
# training from 2019-02-24 15:00:00 to 2019-02-24 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 24.923562344916455
# Training time: 0.12356400489807129
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 24.923562344916455
# Training time: 0.13026022911071777
# training No update model
# correlated intersections: ['K504']
# RMSE: 17.429710261639105
#
#
# training from 2019-02-24 18:00:00 to 2019-02-24 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 15.735876138669957
# Training time: 0.12284278869628906
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 15.735876138669957
# Training time: 0.11420011520385742
# training No update model
# correlated intersections: ['K504']
# RMSE: 24.873924040407633
#
#
# training from 2019-02-24 21:00:00 to 2019-02-25 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 31.275197848907066
# Training time: 0.11534428596496582
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 31.275197848907066
# Training time: 0.1237790584564209
# training No update model
# correlated intersections: ['K504']
# RMSE: 38.384724630521156
#
#
# training from 2019-02-25 00:00:00 to 2019-02-25 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 28.486987974981115
# Training time: 0.14561891555786133
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 28.486987974981115
# Training time: 0.11745905876159668
# training No update model
# correlated intersections: ['K504']
# RMSE: 42.850188702910046
#
#
# training from 2019-02-25 03:00:00 to 2019-02-25 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 19.671162150755816
# Training time: 0.1230461597442627
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 19.671162150755816
# Training time: 0.12655377388000488
# training No update model
# correlated intersections: ['K504']
# RMSE: 37.80121054350889
#
#
# training from 2019-02-25 06:00:00 to 2019-02-25 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 14.13149685954078
# Training time: 0.11145401000976562
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 14.13149685954078
# Training time: 0.1194159984588623
# training No update model
# correlated intersections: ['K504']
# RMSE: 15.527337853772465
#
#
# training from 2019-02-25 09:00:00 to 2019-02-25 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 24.520689655705166
# Training time: 0.11655783653259277
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 24.520689655705166
# Training time: 0.12221503257751465
# training No update model
# correlated intersections: ['K504']
# RMSE: 13.665302549684514
#
#
# training from 2019-02-25 12:00:00 to 2019-02-25 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 34.19618262686641
# Training time: 0.1181790828704834
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 34.19618262686641
# Training time: 0.12072396278381348
# training No update model
# correlated intersections: ['K504']
# RMSE: 23.955179961182846
#
#
# training from 2019-02-25 15:00:00 to 2019-02-25 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 33.018994962298784
# Training time: 0.11567807197570801
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 33.018994962298784
# Training time: 0.1220848560333252
# training No update model
# correlated intersections: ['K504']
# RMSE: 26.1020301701593
#
#
# training from 2019-02-25 18:00:00 to 2019-02-25 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 11.70530674235482
# Training time: 0.12282705307006836
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 11.70530674235482
# Training time: 0.11966490745544434
# training No update model
# correlated intersections: ['K504']
# RMSE: 20.46934711080395
#
#
# training from 2019-02-25 21:00:00 to 2019-02-26 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 29.119282566497066
# Training time: 0.12435197830200195
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 29.119282566497066
# Training time: 0.12129592895507812
# training No update model
# correlated intersections: ['K504']
# RMSE: 35.67821717328463
#
#
# training from 2019-02-26 00:00:00 to 2019-02-26 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 39.52676450589762
# Training time: 0.12177896499633789
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 39.52676450589762
# Training time: 0.12204384803771973
# training No update model
# correlated intersections: ['K504']
# RMSE: 45.004485182295305
#
#
# training from 2019-02-26 03:00:00 to 2019-02-26 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 29.628787543021925
# Training time: 0.1219170093536377
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 29.628787543021925
# Training time: 0.12253284454345703
# training No update model
# correlated intersections: ['K504']
# RMSE: 38.6820094044053
#
#
# training from 2019-02-26 06:00:00 to 2019-02-26 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 22.69571320644537
# Training time: 0.12096905708312988
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 22.69571320644537
# Training time: 0.11720705032348633
# training No update model
# correlated intersections: ['K504']
# RMSE: 18.160375129757526
#
#
# training from 2019-02-26 09:00:00 to 2019-02-26 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 29.34437919486509
# Training time: 0.11682772636413574
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 29.34437919486509
# Training time: 0.12078523635864258
# training No update model
# correlated intersections: ['K504']
# RMSE: 21.02561696130498
#
#
# training from 2019-02-26 12:00:00 to 2019-02-26 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 41.27902181013453
# Training time: 0.11942505836486816
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 41.27902181013453
# Training time: 0.12310099601745605
# training No update model
# correlated intersections: ['K504']
# RMSE: 27.942987436475004
#
#
# training from 2019-02-26 15:00:00 to 2019-02-26 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 30.90374282834979
# Training time: 0.12253403663635254
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 30.90374282834979
# Training time: 0.12333798408508301
# training No update model
# correlated intersections: ['K504']
# RMSE: 23.15711188932436
#
#
# training from 2019-02-26 18:00:00 to 2019-02-26 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 11.59506538928677
# Training time: 0.1191108226776123
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 11.59506538928677
# Training time: 0.12156391143798828
# training No update model
# correlated intersections: ['K504']
# RMSE: 17.187910151356206
#
#
# training from 2019-02-26 21:00:00 to 2019-02-27 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 24.200697657089222
# Training time: 0.14815115928649902
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 24.200697657089222
# Training time: 0.12182021141052246
# training No update model
# correlated intersections: ['K504']
# RMSE: 36.479392727264525
#
#
# training from 2019-02-27 00:00:00 to 2019-02-27 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 33.92996902226058
# Training time: 0.11892390251159668
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 33.92996902226058
# Training time: 0.12388467788696289
# training No update model
# correlated intersections: ['K504']
# RMSE: 43.41164501434566
#
#
# training from 2019-02-27 03:00:00 to 2019-02-27 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 25.65367345847496
# Training time: 0.12153291702270508
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 25.65367345847496
# Training time: 0.12243914604187012
# training No update model
# correlated intersections: ['K504']
# RMSE: 36.300612902130354
#
#
# training from 2019-02-27 06:00:00 to 2019-02-27 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 19.18396480436811
# Training time: 0.1237020492553711
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 19.18396480436811
# Training time: 0.11842513084411621
# training No update model
# correlated intersections: ['K504']
# RMSE: 15.945403887997545
#
#
# training from 2019-02-27 09:00:00 to 2019-02-27 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 46.90372036816483
# Training time: 0.11981511116027832
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 46.90372036816483
# Training time: 0.11664104461669922
# training No update model
# correlated intersections: ['K504']
# RMSE: 34.042434241716066
#
#
# training from 2019-02-27 12:00:00 to 2019-02-27 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 44.56006195118842
# Training time: 0.12321686744689941
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 44.56006195118842
# Training time: 0.11943602561950684
# training No update model
# correlated intersections: ['K504']
# RMSE: 32.96872963565722
#
#
# training from 2019-02-27 15:00:00 to 2019-02-27 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 40.6891200714331
# Training time: 0.12291479110717773
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 40.6891200714331
# Training time: 0.11370182037353516
# training No update model
# correlated intersections: ['K504']
# RMSE: 30.174197217728512
#
#
# training from 2019-02-27 18:00:00 to 2019-02-27 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 16.068192122815283
# Training time: 0.1194911003112793
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 16.068192122815283
# Training time: 0.1274280548095703
# training No update model
# correlated intersections: ['K504']
# RMSE: 19.603288242336014
#
#
# training from 2019-02-27 21:00:00 to 2019-02-28 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 31.661242318278017
# Training time: 0.12252473831176758
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 31.661242318278017
# Training time: 0.12005925178527832
# training No update model
# correlated intersections: ['K504']
# RMSE: 38.54646648040518
#
#
# training from 2019-02-28 00:00:00 to 2019-02-28 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 33.814960270358704
# Training time: 0.12281203269958496
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 33.814960270358704
# Training time: 0.12324690818786621
# training No update model
# correlated intersections: ['K504']
# RMSE: 42.024600136129344
#
#
# training from 2019-02-28 03:00:00 to 2019-02-28 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 25.707517671758
# Training time: 0.12309885025024414
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 25.707517671758
# Training time: 0.11550021171569824
# training No update model
# correlated intersections: ['K504']
# RMSE: 36.233691105016476
#
#
# training from 2019-02-28 06:00:00 to 2019-02-28 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 21.34050193189181
# Training time: 0.12270402908325195
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 21.34050193189181
# Training time: 0.11366105079650879
# training No update model
# correlated intersections: ['K504']
# RMSE: 16.17620431935875
#
#
# training from 2019-02-28 09:00:00 to 2019-02-28 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 21.488647302485678
# Training time: 0.11842823028564453
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 21.488647302485678
# Training time: 0.12129569053649902
# training No update model
# correlated intersections: ['K504']
# RMSE: 12.765997929069234
#
#
# training from 2019-02-28 12:00:00 to 2019-02-28 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 34.606865385873036
# Training time: 0.12402725219726562
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 34.606865385873036
# Training time: 0.11763596534729004
# training No update model
# correlated intersections: ['K504']
# RMSE: 21.192079842405157
#
#
# training from 2019-02-28 15:00:00 to 2019-02-28 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 30.7862018145787
# Training time: 0.12225008010864258
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 30.7862018145787
# Training time: 0.11562490463256836
# training No update model
# correlated intersections: ['K504']
# RMSE: 21.981579785209153
#
#
# training from 2019-02-28 18:00:00 to 2019-02-28 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 12.679217561955408
# Training time: 0.11568617820739746
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 12.679217561955408
# Training time: 0.11917591094970703
# training No update model
# correlated intersections: ['K504']
# RMSE: 20.81624755111677
#
#
# training from 2019-02-28 21:00:00 to 2019-03-01 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 21.90212812839735
# Training time: 0.1255488395690918
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 21.90212812839735
# Training time: 0.11325287818908691
# training No update model
# correlated intersections: ['K504']
# RMSE: 34.70470786574748
#
#
# training from 2019-03-01 00:00:00 to 2019-03-01 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 32.59961633749027
# Training time: 0.12065720558166504
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 32.59961633749027
# Training time: 0.11981725692749023
# training No update model
# correlated intersections: ['K504']
# RMSE: 45.27600631732966
#
#
# training from 2019-03-01 03:00:00 to 2019-03-01 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 22.046806481333995
# Training time: 0.12179398536682129
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 22.046806481333995
# Training time: 0.11861824989318848
# training No update model
# correlated intersections: ['K504']
# RMSE: 38.610729754155614
#
#
# training from 2019-03-01 06:00:00 to 2019-03-01 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 18.462496297392995
# Training time: 0.11910676956176758
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 18.462496297392995
# Training time: 0.11879301071166992
# training No update model
# correlated intersections: ['K504']
# RMSE: 17.011273404761987
#
#
# training from 2019-03-01 09:00:00 to 2019-03-01 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 22.32351233298334
# Training time: 0.1265869140625
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 22.32351233298334
# Training time: 0.11988401412963867
# training No update model
# correlated intersections: ['K504']
# RMSE: 15.196507424096664
#
#
# training from 2019-03-01 12:00:00 to 2019-03-01 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 34.40603712468206
# Training time: 0.11453795433044434
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 34.40603712468206
# Training time: 0.12302517890930176
# training No update model
# correlated intersections: ['K504']
# RMSE: 24.669702841364952
#
#
# training from 2019-03-01 15:00:00 to 2019-03-01 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 32.46242381525042
# Training time: 0.12365388870239258
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 32.46242381525042
# Training time: 0.11926627159118652
# training No update model
# correlated intersections: ['K504']
# RMSE: 23.82993973622324
#
#
# training from 2019-03-01 18:00:00 to 2019-03-01 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 13.039586755488314
# Training time: 0.12412214279174805
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 13.039586755488314
# Training time: 0.11610007286071777
# training No update model
# correlated intersections: ['K504']
# RMSE: 16.55945487189409
#
#
# training from 2019-03-01 21:00:00 to 2019-03-02 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 22.522688213776792
# Training time: 0.12428808212280273
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 22.522688213776792
# Training time: 0.12479162216186523
# training No update model
# correlated intersections: ['K504']
# RMSE: 31.032364225023706
#
#
# training from 2019-03-02 00:00:00 to 2019-03-02 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 36.486491172568755
# Training time: 0.24145007133483887
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 36.486491172568755
# Training time: 0.12898993492126465
# training No update model
# correlated intersections: ['K504']
# RMSE: 43.19298451291381
#
#
# training from 2019-03-02 03:00:00 to 2019-03-02 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 31.12537258185635
# Training time: 0.13051605224609375
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 31.12537258185635
# Training time: 0.12149882316589355
# training No update model
# correlated intersections: ['K504']
# RMSE: 44.35093565150641
#
#
# training from 2019-03-02 06:00:00 to 2019-03-02 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 15.022194781707842
# Training time: 0.12402677536010742
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 15.022194781707842
# ...
# correlated intersections: ['K504']
# RMSE: 16.144580869600738
#
#
# training from 2020-03-28 12:00:00 to 2020-03-28 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 34.74233594948046
# Training time: 0.11735987663269043
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 34.74233594948046
# Training time: 0.11754322052001953
# training No update model
# correlated intersections: ['K504']
# RMSE: 18.74912351467021
#
#
# training from 2020-03-28 15:00:00 to 2020-03-28 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 15.118005065101595
# Training time: 0.1268758773803711
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 15.118005065101595
# Training time: 0.11638474464416504
# training No update model
# correlated intersections: ['K504']
# RMSE: 18.50065570390978
#
#
# training from 2020-03-28 18:00:00 to 2020-03-28 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 13.167759588408538
# Training time: 0.12292289733886719
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 13.167759588408538
# Training time: 0.11658501625061035
# training No update model
# correlated intersections: ['K504']
# RMSE: 34.77076155874357
#
#
# training from 2020-03-28 21:00:00 to 2020-03-29 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 19.523226476950793
# Training time: 0.12667608261108398
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 19.523226476950793
# Training time: 0.11526989936828613
# training No update model
# correlated intersections: ['K504']
# RMSE: 41.83905435985095
#
#
# training from 2020-03-29 00:00:00 to 2020-03-29 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 21.084734039619384
# Training time: 0.12509989738464355
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 21.084734039619384
# Training time: 0.1173558235168457
# training No update model
# correlated intersections: ['K504']
# RMSE: 43.95884722127546
#
#
# training from 2020-03-29 03:00:00 to 2020-03-29 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 23.734873883828623
# Training time: 0.12616920471191406
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 23.734873883828623
# Training time: 0.12431597709655762
# training No update model
# correlated intersections: ['K504']
# RMSE: 44.92271602473589
#
#
# training from 2020-03-29 06:00:00 to 2020-03-29 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 20.72921042381793
# Training time: 0.1254439353942871
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 20.72921042381793
# Training time: 0.12467813491821289
# training No update model
# correlated intersections: ['K504']
# RMSE: 43.40474259441588
#
#
# training from 2020-03-29 09:00:00 to 2020-03-29 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 10.419709719899718
# Training time: 0.12638187408447266
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 10.419709719899718
# Training time: 0.11748814582824707
# training No update model
# correlated intersections: ['K504']
# RMSE: 29.83981588107417
#
#
# training from 2020-03-29 12:00:00 to 2020-03-29 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 24.90209344236946
# Training time: 0.1244502067565918
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 24.90209344236946
# Training time: 0.14220905303955078
# training No update model
# correlated intersections: ['K504']
# RMSE: 15.505490714890977
#
#
# training from 2020-03-29 15:00:00 to 2020-03-29 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 15.914747085790824
# Training time: 0.12687087059020996
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 15.914747085790824
# Training time: 0.1346111297607422
# training No update model
# correlated intersections: ['K504']
# RMSE: 22.08383366239919
#
#
# training from 2020-03-29 18:00:00 to 2020-03-29 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 10.081556389558104
# Training time: 0.12955284118652344
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 10.081556389558104
# Training time: 0.11957216262817383
# training No update model
# correlated intersections: ['K504']
# RMSE: 36.03890076242701
#
#
# training from 2020-03-29 21:00:00 to 2020-03-30 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 17.164335419712312
# Training time: 0.1281120777130127
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 17.164335419712312
# Training time: 0.13868975639343262
# training No update model
# correlated intersections: ['K504']
# RMSE: 41.271888428009476
#
#
# training from 2020-03-30 00:00:00 to 2020-03-30 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 22.281193159333178
# Training time: 0.12788891792297363
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 22.281193159333178
# Training time: 0.1185610294342041
# training No update model
# correlated intersections: ['K504']
# RMSE: 50.09154948769428
#
#
# training from 2020-03-30 03:00:00 to 2020-03-30 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 13.172792450255185
# Training time: 0.12624692916870117
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 13.172792450255185
# Training time: 0.12784099578857422
# training No update model
# correlated intersections: ['K504']
# RMSE: 38.33816718984571
#
#
# training from 2020-03-30 06:00:00 to 2020-03-30 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 20.29510147298673
# Training time: 0.13794922828674316
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 20.29510147298673
# Training time: 0.1297898292541504
# training No update model
# correlated intersections: ['K504']
# RMSE: 17.361641777914016
#
#
# training from 2020-03-30 09:00:00 to 2020-03-30 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 14.373303122503442
# Training time: 0.11708593368530273
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 14.373303122503442
# Training time: 0.11951708793640137
# training No update model
# correlated intersections: ['K504']
# RMSE: 23.983047856197434
#
#
# training from 2020-03-30 12:00:00 to 2020-03-30 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 25.827424323148616
# Training time: 0.12373185157775879
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 25.827424323148616
# Training time: 0.125535249710083
# training No update model
# correlated intersections: ['K504']
# RMSE: 14.680275816444151
#
#
# training from 2020-03-30 15:00:00 to 2020-03-30 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 26.75788093056943
# Training time: 0.13068580627441406
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 26.75788093056943
# Training time: 0.12185192108154297
# training No update model
# correlated intersections: ['K504']
# RMSE: 14.19157828308885
#
#
# training from 2020-03-30 18:00:00 to 2020-03-30 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 10.065679012462775
# Training time: 0.12705278396606445
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 10.065679012462775
# Training time: 0.17480802536010742
# training No update model
# correlated intersections: ['K504']
# RMSE: 32.01162317900621
#
#
# training from 2020-03-30 21:00:00 to 2020-03-31 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 15.579504076369858
# Training time: 0.13077974319458008
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 15.579504076369858
# Training time: 0.11796402931213379
# training No update model
# correlated intersections: ['K504']
# RMSE: 41.96681137322608
#
#
# training from 2020-03-31 00:00:00 to 2020-03-31 03:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 24.08053301553975
# Training time: 0.1242830753326416
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 24.08053301553975
# Training time: 0.13501381874084473
# training No update model
# correlated intersections: ['K504']
# RMSE: 46.5168820161025
#
#
# training from 2020-03-31 03:00:00 to 2020-03-31 06:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 13.770621078325135
# Training time: 0.13687896728515625
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 13.770621078325135
# Training time: 0.13021421432495117
# training No update model
# correlated intersections: ['K504']
# RMSE: 42.62013122853448
#
#
# training from 2020-03-31 06:00:00 to 2020-03-31 09:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 20.040398804128515
# Training time: 0.1292710304260254
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 20.040398804128515
# Training time: 0.11961102485656738
# training No update model
# correlated intersections: ['K504']
# RMSE: 22.91466314632129
#
#
# training from 2020-03-31 09:00:00 to 2020-03-31 12:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 21.022634751024906
# Training time: 0.1253800392150879
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 21.022634751024906
# Training time: 0.12634778022766113
# training No update model
# correlated intersections: ['K504']
# RMSE: 14.854506793236606
#
#
# training from 2020-03-31 12:00:00 to 2020-03-31 15:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 26.512401054373946
# Training time: 0.14032506942749023
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 26.512401054373946
# Training time: 0.11644124984741211
# training No update model
# correlated intersections: ['K504']
# RMSE: 15.254203842327572
#
#
# training from 2020-03-31 15:00:00 to 2020-03-31 18:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 30.617976913145426
# Training time: 0.12933874130249023
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 30.617976913145426
# Training time: 0.1262989044189453
# training No update model
# correlated intersections: ['K504']
# RMSE: 17.906824339065714
#
#
# training from 2020-03-31 18:00:00 to 2020-03-31 21:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 12.682816566503291
# Training time: 0.1280970573425293
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 12.682816566503291
# Training time: 0.12209677696228027
# training No update model
# correlated intersections: ['K504']
# RMSE: 30.143969123387166
#
#
# training from 2020-03-31 21:00:00 to 2020-04-01 00:00:00
# training incremental weighted update model
# correlated intersections: ['K504']
# RMSE: 19.678594215860542
# Training time: 0.1257636547088623
# training incremental static update model
# correlated intersections: ['K504']
# RMSE: 19.678594215860542
# Training time: 0.11896920204162598
# training No update model
# correlated intersections: ['K504']
# RMSE: 41.45644805046541
#
#
# training from 2020-04-01 00:00:00 to 2020-04-01 03:00:00
# training incremental weighted update model
# correlated intersections: ['K502']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 57
#      55 # ------------------------------------ training incremental models ---------------------------------------- #
#      56 print("training incremental weighted update model")
# ---> 57 model_results,top_corr_df = test_then_train_weighted_model(incremental_data, incremental_ae, number_of_cols, target, results_load_weighted_path, results_save_weighted_path, hidden_size, output_pred, num_layers, dropout, device,sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained=True, static = False, base=False)
#      58 errors[trajectory][direction][threshold]['incremental_weighted_update'][incremental_time] = model_results
#      60 print("training incremental static update model")
#
# Cell In[58], line 17, in test_then_train_weighted_model(data, ae_score, number_of_cols, target, results_load_path, results_save_path, hidden_size, output_pred, num_layers, dropout, device, sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained, static, base)
#      15 n_obs = sequence_length * n_features # number of columns in the input
#      16 reframed = series_to_supervised(df, sequence_length, output_pred)
# ---> 17 train_X, train_y, scl = preprocess_df(reframed, n_obs, n_features, sequence_length)
#      20 # # # ------------------------------------ modelling ---------------------------------------------- #
#      21 # define model, loss function and optimizer
#      22 model = LSTM_uni(input_dim = n_features, hidden_dim = hidden_size, output_dim = output_pred, layer_dim = num_layers, dropout_prob= dropout, device = device)
#
# Cell In[30], line 6, in preprocess_df(df, n_obs, n_features, sequence_length)
#       4 df_train = df.values
#       5 train_X, train_y = df_train[:, :n_obs], df_train[:, -n_features]
# ----> 6 scl = scaler.fit(train_X) # fit only on training data
#       7 train_X = scl.transform(train_X)
#       8 train_X = train_X.reshape((train_X.shape[0], sequence_length, n_features))
#
# File /opt/homebrew/anaconda3/envs/OWRI/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:824, in StandardScaler.fit(self, X, y, sample_weight)
#     822 # Reset internal state before fitting
#     823 self._reset()
# --> 824 return self.partial_fit(X, y, sample_weight)
#
# File /opt/homebrew/anaconda3/envs/OWRI/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:861, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     858 self._validate_params()
#     860 first_call = not hasattr(self, "n_samples_seen_")
# --> 861 X = self._validate_data(
#     862     X,
#     863     accept_sparse=("csr", "csc"),
#     864     dtype=FLOAT_DTYPES,
#     865     force_all_finite="allow-nan",
#     866     reset=first_call,
#     867 )
#     868 n_features = X.shape[1]
#     870 if sample_weight is not None:
#
# File /opt/homebrew/anaconda3/envs/OWRI/lib/python3.10/site-packages/sklearn/base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File /opt/homebrew/anaconda3/envs/OWRI/lib/python3.10/site-packages/sklearn/utils/validation.py:931, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929     n_samples = _num_samples(array)
#     930     if n_samples < ensure_min_samples:
# --> 931         raise ValueError(
#     932             "Found array with %d sample(s) (shape=%s) while a"
#     933             " minimum of %d is required%s."
#     934             % (n_samples, array.shape, ensure_min_samples, context)
#     935         )
#     937 if ensure_min_features > 0 and array.ndim == 2:
#     938     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 12)) while a minimum of 1 is required by StandardScaler.

# %%
# ------------------------------------ save results ---------------------------------------- #
with open(os.path.join(base_result_path, f'univariate_real_time_{outlier_model_name}_threshold_{threshold}_{time_window}H_{target}.pkl'), 'wb') as f:
    pickle.dump(errors, f)

# %% [markdown]
# #### ---------------------------- METR-LA data processing ----------------------------

# %%
# results save path
outlier_model_name = 'PW-AE'
data_name = 'METR-LA'
base_result_path = f'../results/{data_name}/real_time_modeling'

# %%
with open(f'../data/{data_name}/processed/featured_fpds_raw.pickle', 'rb') as f:
    results = pickle.load(f)

# %%
# load data of correlated results from pickle file
with open(f'../results/{data_name}/outlier_scores/{outlier_model_name}/correlated_results.pickle', 'rb') as f:
    correlated_results = pickle.load(f)

# %%
thresholds = [0,0.05,0.1,0.25,0.5, 1] # thresholds for the percentage of correlated columns to keep
target_intersections = list(np.random.choice(list(results['raw'].keys()), 5, replace=False)) # select 10 intersections randomly from the 207 intersections
# declare variables
threshold = 0.05
time_window = 3
epoch_train = 100
epoch_retrain = 20
batch_size = 64
learning_rate = 0.1
hidden_size = 32
num_layers = 1
dropout = 0.2
sequence_length = 12
output_pred = 1 # number of time steps to predict
base_train_portion = 0.5 # percentage of data to use for training
device = 'mps' if torch.backends.mps.is_available() else 'cpu'

# %%
# ------------------------------------ for metr-la dataset ---------------------------------------- #
errors={}
for target in target_intersections:
    print(f"\n \n ------------------------ Starting target: {target} and threshold: {threshold} ------------------------")
    errors[target]={}
    errors[target][threshold]={}
    errors[target][threshold]['incremental_weighted_update']={}
    errors[target][threshold]['incremental_static_update']={}
    errors[target][threshold]['No_update']={}

    # ------------------------------------ data processing for base model ---------------------------------------- #
    data = merge_trejectory_data_metr(results)# get raw data of the current trajectory and direction
    ae_score = correlated_results['df'] # AE scores of the current trajectory and direction
    data_size = data.shape[0]
    model_start_time  = data.index[0]
    model_end_time = data.index[-1]
    baseline_time = data.iloc[int(data_size*base_train_portion)].name
    incremental_time = baseline_time
    base_ae = ae_score[ae_score.index<=baseline_time]
    stream_ae = ae_score[ae_score.index>baseline_time]
    base_data = data[data.index<=baseline_time]
    stream_data = data[data.index>baseline_time]
    number_of_cols = math.ceil(len(ae_score.columns)*threshold) # number of outlier weighted intersections
    if number_of_cols==0: # if threshold is 0, then use the target intersection only
        number_of_cols=1

    # ------------------------------------ training base model ---------------------------------------- #
    print(f"training from {model_start_time} to {baseline_time}")
    exp_name = f'univariate_{outlier_model_name}_real_time_base_model.pt'
    results_save_path = os.path.join(base_result_path, exp_name)
    results_save_weighted_path  = results_save_path
    base_model_path = results_save_path
    results_load_path = "None"
    results_load_weighted_path = "None"
    fixed_base_corr_df = "None"
    model_results, fixed_base_corr_df = test_then_train_weighted_model(base_data, base_ae, number_of_cols, target, results_load_path, base_model_path, hidden_size, output_pred, num_layers, dropout, device, sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained=False, static = False, base=False)
    errors[target][threshold]['base_model'] = model_results

    # # ------------------------------------ incremental training ---------------------------------------- #
    incremental_time = incremental_time + pd.DateOffset(hours=time_window)
    while(incremental_time<model_end_time):
        print(f"\n\ntraining from {baseline_time} to {incremental_time}")
        incremental_ae = stream_ae[(stream_ae.index>baseline_time) & (stream_ae.index<=incremental_time)]
        incremental_data = stream_data[(stream_data.index>baseline_time) & (stream_data.index<=incremental_time)]
        exp_name = f'univariate_real_time_{outlier_model_name}_incremental_static_{incremental_time}.pkl'
        exp_name_weighted = f'univariate_real_time_{outlier_model_name}_incremental_weighted_{incremental_time}.pkl'
        results_load_path = results_save_path
        results_save_path = os.path.join(base_result_path, exp_name)
        results_load_weighted_path = results_save_weighted_path
        results_save_weighted_path = os.path.join(base_result_path, exp_name_weighted)

        # ------------------------------------ training incremental models ---------------------------------------- #
        print("training incremental weighted update model")
        model_results,top_corr_df = test_then_train_weighted_model(incremental_data, incremental_ae, number_of_cols, target, results_load_weighted_path, results_save_weighted_path, hidden_size, output_pred, num_layers, dropout, device,sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained=True, static = False, base=False)
        errors[target][threshold]['incremental_weighted_update'][incremental_time] = model_results

        print("training incremental static update model")
        model_results,top_corr_df = test_then_train_weighted_model(incremental_data, incremental_ae, number_of_cols, target, results_load_path, results_save_path, hidden_size, output_pred, num_layers, dropout, device, sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained=True, static = True, base=False)
        errors[target][threshold]['incremental_static_update'][incremental_time] = model_results

        print("training No update model")
        model_results,top_corr_df = test_then_train_weighted_model(incremental_data, incremental_ae, number_of_cols, target, base_model_path, results_save_weighted_path, hidden_size, output_pred, num_layers, dropout, device, sequence_length, epoch_train, epoch_retrain, fixed_base_corr_df, pre_trained=True, static = True, base=True)
        errors[target][threshold]['No_update'][incremental_time] = model_results


        baseline_time = incremental_time # update baseline time
        incremental_time = incremental_time + pd.DateOffset(hours=time_window) # update incremental time

# %%
# ------------------------------------ save results ---------------------------------------- #
with open(os.path.join(base_result_path, f'univariate_real_time_{outlier_model_name}_threshold_{threshold}_{time_window}H_{target}.pkl'), 'wb') as f:
    pickle.dump(errors, f)

# %% [markdown]
# # EXTRA

# %%
# def test_then_train_model(data, ae_score, number_of_cols, target, results_load_path, results_save_path, base_mode_path, pre_trained=True) :
#     result_dict = {}

#     # ------------------------------------ data processing ---------------------------------------- #
#     top_corr_df = ae_score.corr()[target].sort_values(ascending=False)[:number_of_cols] # get the top correlated intersections
#     isct_inc = top_corr_df.index.tolist()
#     print("correlated intersections: {}".format(isct_inc))
#     df = data[isct_inc].copy(deep=True)
#     # df = df.mul(top_corr_df, axis=1)
#     df = df.astype('float32')
#     sequence_length = 12 # number of time steps to look back
#     n_features = len(isct_inc) # number of features (correlated intersections)
#     output_pred = 1 # number of time steps to predict
#     n_obs = sequence_length * n_features # number of columns in the input
#     reframed = series_to_supervised(df, sequence_length, output_pred)
#     train_X, train_y, scl = preprocess_df(reframed, n_obs, n_features, sequence_length)


# # # # ------------------------------------ modelling ---------------------------------------------- #
#     # define model, loss function and optimizer
#     model = LSTM_uni(input_dim = n_features, hidden_dim = 32, layer_dim = 1, output_dim = output_pred, dropout_prob= 0.2)
#     model = model.to(device)
#     loss_fn = torch.nn.MSELoss()
#     optimiser = torch.optim.Adam(model.parameters(), lr=0.01)
#     if pre_trained==True:
#         model, optimiser = load_ckp(results_load_path, model, optimiser)
    

#     # ------------------------------------ testing ---------------------------------------------- #
#     yhat = model_evaluation( model, train_X , device)
#     result_dict['RMSE'] = sqrt(mean_squared_error(yhat,train_y))
#     result_dict['MAE'] = mean_absolute_error(yhat,train_y)
#     result_dict['df'] = pd.DataFrame({"Real":train_y,"Predicted":yhat})
#     print("RMSE: {}".format(result_dict['RMSE']))


#    # ------------------------------------ training ---------------------------------------------- #
#     start = time.time()
#     if pre_trained==False:
#         history, model = train_model(model, train_X,train_y, loss_fn, optimiser, device, epochs=50)
#     else:
#         history, model = train_model(model, train_X,train_y, loss_fn, optimiser, device, epochs=1)
#     end = time.time()
#     checkpoint = {'state_dict': model.state_dict(),'optimizer': optimiser.state_dict()}
#     torch.save(checkpoint, results_save_path)
#     print("Training time: {}".format(end-start))
#     result_dict['history'] = history
#     result_dict['intersedctions'] = isct_inc
#     result_dict['train_time'] = end-start

    
#     return result_dict, top_corr_df

# %%
# def test_base_model(data, ae_score, number_of_cols, target, results_load_path, top_corr_df,pre_trained=True):
#     result_dict = {}

#     # ------------------------------------ data processing ---------------------------------------- #
#     isct_inc = top_corr_df.index.tolist()
#     print("correlated intersections: {}".format(isct_inc))
#     df = data[isct_inc].copy(deep=True)
#     df = df.mul(top_corr_df, axis=1)
#     df = df.astype('float32')
#     sequence_length = 12 # number of time steps to look back
#     n_features = len(isct_inc) # number of features (correlated intersections)
#     output_pred = 1 # number of time steps to predict
#     n_obs = sequence_length * n_features # number of columns in the input
#     reframed = series_to_supervised(df, sequence_length, output_pred)
#     train_X, train_y, scl = preprocess_df(reframed, n_obs, n_features, sequence_length)


# # # # ------------------------------------ modelling ---------------------------------------------- #
#     # define model, loss function and optimizer
#     model = LSTM_uni(input_dim = n_features, hidden_dim = 32, layer_dim = 1, output_dim = output_pred, dropout_prob= 0.2)
#     model = model.to(device)
#     loss_fn = torch.nn.MSELoss()
#     optimiser = torch.optim.Adam(model.parameters(), lr=0.01)
#     if pre_trained==True:
#         model, optimiser = load_ckp(results_load_path, model, optimiser)
    

#     # ------------------------------------ testing ---------------------------------------------- #
#     yhat = model_evaluation( model, train_X , device)
#     result_dict['RMSE'] = sqrt(mean_squared_error(yhat,train_y))
#     result_dict['MAE'] = mean_absolute_error(yhat,train_y)
#     result_dict['df'] = pd.DataFrame({"Real":train_y,"Predicted":yhat})
#     result_dict['intersedctions'] = isct_inc
#     print("RMSE: {}".format(result_dict['RMSE']))
    
#     return result_dict, top_corr_df
